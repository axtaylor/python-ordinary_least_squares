# %% [markdown]
# ## Linear Regression Demonstration
#
# Using `regression-inference` package

# %%
from regression_inference import LinearRegression, summary

# %%
import numpy as np
import pandas as pd

# %%
#© Copyright 2007 - 2025, scikit-learn developers (BSD License).
from sklearn.datasets import fetch_california_housing
data = fetch_california_housing(as_frame = True).frame

# %% [markdown]
# ### Model Fitting
#
# - Fit the Linear Regression on the training set

# %%
data['const'] = np.ones(len(data))

features = data[[
    'const', 'MedInc', 'HouseAge', 'AveRooms',
    'AveBedrms', 'AveOccup', 'MedHouseVal'
]].dropna()

X = features.drop(columns=['MedHouseVal'])
y = features['MedHouseVal']

lm = LinearRegression().fit(X=X, y=y, cov_type=None, alpha=0.05)

# %%
# Printing the fitted model calls summary(model)

print(lm)
#print(summary(lm))
# Out:
# =============================================
# OLS Regression Results
# ---------------------------------------------
# Dependent:                        MedHouseVal
# ---------------------------------------------
#
# const                              -0.3857***
#                                      (0.0247)
#
# MedInc                              0.5374***
#                                      (0.0041)
#
# HouseAge                            0.0159***
#                                      (0.0004)
#
# AveRooms                           -0.2139***
#                                      (0.0060)
#
# AveBedrms                           0.9985***
#                                      (0.0295)
#
# AveOccup                           -0.0047***
#                                      (0.0005)
#
# ---------------------------------------------
# R-squared                               0.539
# Adjusted R-squared                      0.539
# F Statistic                          4830.447
# Observations                        20640.000
# Log Likelihood                     -24244.367
# AIC                                 48500.734
# BIC                                 48548.344
# TSS                                 27483.198
# RSS                                 12662.112
# ESS                                 14821.086
# MSE                                     0.614
# =============================================
# *p<0.1; **p<0.05; ***p<0.01

# %% [markdown]
# ### Model Predictions
#
# - Predict a set of data
#
# - Predict new values
#
# - Predict with inference table
#
# - Predict at sample mean
#
# - Predict over range of specified values

# %%
# Predict the entire training set

#print(list(lm.X @ lm.theta))
# Out:
# [np.float64(4.255838468093787), np.float64(4.035400653362899), np.float64(3.626081849618088), np.float64(3.287711147381182), np.float64(2.2323937511821574), np.float64(2.682640823633621), np.float64(2.29126813157259), np.float64(2.142166726853107), np.float64(1.5870102139898419), np.float64(2.3388152260400594), np.float64(2.056901146946954), np.float64(2.1899378578229496), np.float64(1.954130121133608), np.float64(2.107721865442241), np.float64(1.5569590437787322), np.float64(1.7005166996941155), np.float64(1.696195102541146), np.float64(1.6677789760205841), np.float64(1.4082747414663443), np.float64(1.7400234813772941), np.float64(1.10648230334899), np.float64(1.2333299694987572), np.float64(1.396858805607864), np.float64(1.5237523073527626), np.float64(1.7325908098172011), np.float64(1.6149149778577239), np.float64(1.7101742213397393), np.float64(1.434609212130861), np.float64(1.3765107416885676), np.float64(1.3593681123903862), np.float64(1.5138027932749458), np.float64(1.5262574982845056), np.float64(1.3194568469258743), np.float64(1.1551244447933955), np.float64(1.8859728368385578), np.float64(1.2628028540922214), np.float64(1.0785447032452327), np.float64(1.3514332160667843), np.float64(2.348301258020367), np.float64(2.1005700419315603), np.float64(1.713425832617548), np.float64(1.5478322194258958), np.float64(1.1917079247344615), np.float64(2.5515852589300714), np.float64(2.054563357489397), np.float64(2.0400400338744986), np.float64(1.753318545947522), np.float64(1.5988067672452575), np.float64(1.1304076711178526), np.float64(1.6826781872067786), np.float64(1.030258683515728), np.float64(1.2301808335458186), np.float64(1.0753669237321009), np.float64(1.3631476135050618), np.float64(1.2237514545831123), np.float64(1.3699818562544042), np.float64(1.3255387284597828), np.float64(0.9305227564992058), np.float64(1.2213406113354563), np.float64(1.1758561208572351), np.float64(2.0937115386450444), np.float64(3.6662374520561474), np.float64(1.1003397413920672), np.float64(0.9062265463793633), np.float64(1.7911598467100562), np.float64(1.0122862951321792), np.float64(0.9252805348979436), np.float64(1.9894332976338989), np.float64(1.2544150778524656), np.float64(0.9291208226348184), np.float64(0.8664467166591341), np.float64(1.0747358834370622), np.float64(1.467718530858844), np.float64(0.8048686930423612), np.float64(1.1219102688865468), np.float64(0.8207337764952578), np.float64(1.3670987033006095), np.float64(0.42170817221286305), np.float64(0.39615218197916446), np.float64(1.4779425082113802), np.float64(0.9950322462482037), np.float64(1.247737592859234), np.float64(1.5235634899286845), np.float64(1.3869276454800485), np.float64(1.0163376999818492), np.float64(1.5225358422105186), np.float64(1.456762496560343), np.float64(0.6595273182151812), np.float64(0.7798995326371818), np.float64(1.3756828876031375), np.float64(1.4770803590814723), np.float64(1.3217555302720567), np.float64(1.1227763431711408), np.float64(1.8481203499555376), np.float64(1.7595346122854345), np.float64(1.8327034486072842), np.float64(1.914746901524274), np.float64(1.529035621382157), np.float64(0.9951858691584967), np.float64(1.9082450213800972), np.float64(1.7376068824820585), np.float64(2.01964454762027), np.float64(2.1634510613265716), np.float64(2.2090060322305876), np.float64(2.0398645347704596), np.float64(2.674586238912916), np.float64(2.296353532539628), np.float64(2.332582847266514), np.float64(2.533643268053174), np.float64(2.323744393339457), np.float64(3.102651766333551), np.float64(1.8098877111196856), np.float64(1.9305243128257106), np.float64(2.219495209047943), np.float64(2.223555862643331), np.float64(2.1648445722767184), np.float64(1.7592080789586801), np.float64(2.291832927843262), np.float64(3.170848258203276), np.float64(2.7255258503721183), np.float64(3.0689881469307454), np.float64(2.4870954045912876), np.float64(3.3687754649792283), np.float64(2.884877216860046), np.float64(3.787538221571081), np.float64(2.8932901946733622), np.fl ...

# %%
lm.feature_names[1:]
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup'], dtype='object')

# %%
# All predictions are in order of model.feature_names[1:]

lm.predict( X = [8.3252, 41, 6.98412698,  1.02380952, 2.55555556] )
# Out:
# np.float64(4.255838465151851)

# %%
# Predict new values with inference
# return_table requires 2d array

prediction = lm.predict(X = [[8.3252, 41, 6.98412698,  1.02380952, 2.55555556]], return_table = True )

pd.DataFrame(prediction)
# Out:
#                                             features  prediction  std_error  \
# 0  {'MedInc': '8.33', 'HouseAge': '41.00', 'AveRo...      4.2558     0.0156
#
#    t_statistic  P>|t|  ci_low_0.05  ci_high_0.05
# 0     272.8757  0.000       4.2253        4.2864

# %%
prediction_set = [
    [[8.3252, 41, 6.98412698, 1.02380952, 2.55555556]],
    [[8.3014, 21, 6.23813708, 0.97188049, 2.10984183]],
] 

predictions = pd.concat(
    [pd.DataFrame(lm.predict(X = pred, return_table=True)) for pred in prediction_set]
)

predictions
# Out:
#                                             features  prediction  std_error  \
# 0  {'MedInc': '8.33', 'HouseAge': '41.00', 'AveRo...      4.2558     0.0156
# 0  {'MedInc': '8.30', 'HouseAge': '21.00', 'AveRo...      4.0354     0.0149
#
#    t_statistic  P>|t|  ci_low_0.05  ci_high_0.05
# 0     272.8757  0.000       4.2253        4.2864
# 0     270.6509  0.000       4.0062        4.0646

# %%
# Predict at the sample mean
  
sample_mean = (
    [X[i].mean() for i in list(lm.feature_names[1:])] # Preserves ordering
) 

prediction_set = [[sample_mean]] 

predictions = pd.concat(
    [pd.DataFrame(lm.predict(X = pred, return_table=True)) for pred in prediction_set]
)

predictions
# Out:
#                                             features  prediction  std_error  \
# 0  {'MedInc': '3.87', 'HouseAge': '28.64', 'AveRo...      2.0686     0.0055
#
#    t_statistic  P>|t|  ci_low_0.05  ci_high_0.05
# 0     379.3685  0.000       2.0579        2.0792

# %%
'''
Predict each year of HouseAge holding all else at the sample mean

Maintain order of lm.feature_names[1:], ie, ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup']
'''

prev_names, post_names = ['MedInc'], ['AveRooms', 'AveBedrms', 'AveOccup']

mean_prev, mean_post = [X[i].mean() for i in prev_names], [X[i].mean() for i in post_names]


prediction_range = np.linspace(
    X['HouseAge'].min(),
    X['HouseAge'].max(),
    1 + int(X['HouseAge'].max()) - int(X['HouseAge'].min())
)

prediction_set = [
    [mean_prev + [i] + mean_post]
    for i in prediction_range  
] 

predictions = pd.concat(
    [pd.DataFrame(lm.predict(X = pred, return_table=True)) for pred in prediction_set]
)

predictions.head()
# Out:
#                                             features  prediction  std_error  \
# 0  {'MedInc': '3.87', 'HouseAge': '1.00', 'AveRoo...      1.6299     0.0133
# 0  {'MedInc': '3.87', 'HouseAge': '2.00', 'AveRoo...      1.6457     0.0129
# 0  {'MedInc': '3.87', 'HouseAge': '3.00', 'AveRoo...      1.6616     0.0125
# 0  {'MedInc': '3.87', 'HouseAge': '4.00', 'AveRoo...      1.6775     0.0122
# 0  {'MedInc': '3.87', 'HouseAge': '5.00', 'AveRoo...      1.6934     0.0118
#
#    t_statistic  P>|t|  ci_low_0.05  ci_high_0.05
# 0     122.1344  0.000       1.6037        1.6560
# 0     127.1440  0.000       1.6204        1.6711
# 0     132.4456  0.000       1.6370        1.6862
# 0     138.0617  0.000       1.6537        1.7013
# 0     144.0160  0.000       1.6703        1.7164

# %% [markdown]
# ### Coefficient Inference Table
#
# - Comprehensive regression inference

# %%
pd.DataFrame(lm.inference_table())
# Out:
#      feature coefficient std_error  t_statistic  P>|t| ci_low_0.05  \
# 0      const     -0.3857    0.0247     -15.6176  0.000     -0.4341
# 1     MedInc      0.5374    0.0041     130.3086  0.000      0.5293
# 2   HouseAge      0.0159    0.0004      36.0159  0.000       0.015
# 3   AveRooms     -0.2139     0.006     -35.6918  0.000     -0.2256
# 4  AveBedrms      0.9985    0.0295      33.8376  0.000      0.9406
# 5   AveOccup     -0.0047    0.0005      -8.9512  0.000     -0.0057
#
#   ci_high_0.05
# 0      -0.3373
# 1       0.5455
# 2       0.0167
# 3      -0.2021
# 4       1.0563
# 5      -0.0037

# %% [markdown]
# ### Variance Inflation Factor
#
# - Generate a VIF table on the models features

# %%
pd.DataFrame(lm.variance_inflation_factor())
# Out:
#      feature     VIF
# 0     MedInc  2.0649
# 1   HouseAge  1.0346
# 2   AveRooms  7.3916
# 3  AveBedrms  6.5768
# 4   AveOccup  1.0009

# %% [markdown]
# ### Robust Covariance (Preview)
#
# - Preview the effect of robust covariances without applying to the model

# %%
pd.DataFrame(lm.robust_se(type="HC0"))
# Out:
#      feature  robust_se   robust_t  robust_p  ci_low_0.05  ci_high_0.05
# 0      const   0.090548  -4.259892  0.000021    -0.563204     -0.208243
# 1     MedInc   0.010606  50.673000  0.000000     0.516644      0.558221
# 2   HouseAge   0.000560  28.356192  0.000000     0.014774      0.016969
# 3   AveRooms   0.018929 -11.297794  0.000000    -0.250961     -0.176755
# 4  AveBedrms   0.102282   9.761777  0.000000     0.797972      1.198933
# 5   AveOccup   0.001116  -4.212912  0.000025    -0.006889     -0.002514

# %%
pd.DataFrame(lm.robust_se(type="HC1"))
# Out:
#      feature  robust_se   robust_t  robust_p  ci_low_0.05  ci_high_0.05
# 0      const   0.090561  -4.259273  0.000021    -0.563229     -0.208217
# 1     MedInc   0.010607  50.665634  0.000000     0.516641      0.558224
# 2   HouseAge   0.000560  28.352071  0.000000     0.014774      0.016969
# 3   AveRooms   0.018932 -11.296152  0.000000    -0.250966     -0.176750
# 4  AveBedrms   0.102297   9.760358  0.000000     0.797943      1.198962
# 5   AveOccup   0.001116  -4.212300  0.000025    -0.006889     -0.002514

# %%
pd.DataFrame(lm.robust_se(type="HC2"))
# Out:
#      feature  robust_se   robust_t  robust_p  ci_low_0.05  ci_high_0.05
# 0      const   0.102204  -3.774034  0.000161    -0.586052     -0.185394
# 1     MedInc   0.011408  47.108947  0.000000     0.515071      0.559794
# 2   HouseAge   0.000576  27.566135  0.000000     0.014743      0.017000
# 3   AveRooms   0.020602 -10.380413  0.000000    -0.254240     -0.173476
# 4  AveBedrms   0.115616   8.635914  0.000000     0.771836      1.225070
# 5   AveOccup   0.001553  -3.026952  0.002473    -0.007746     -0.001657

# %%
pd.DataFrame(lm.robust_se(type="HC3"))
# Out:
#      feature  robust_se   robust_t      robust_p  ci_low_0.05  ci_high_0.05
# 0      const   0.116087  -3.322717  8.930039e-04    -0.613262     -0.158184
# 1     MedInc   0.012372  43.438051  0.000000e+00     0.513182      0.561683
# 2   HouseAge   0.000595  26.675229  0.000000e+00     0.014705      0.017038
# 3   AveRooms   0.022554  -9.481876  0.000000e+00    -0.258066     -0.169650
# 4  AveBedrms   0.131599   7.587064  3.397282e-14     0.740508      1.256398
# 5   AveOccup   0.002447  -1.921199  5.472040e-02    -0.009498      0.000095

# %% [markdown]
# ### Robust Covariance (Apply on Fit)
#
# - Apply a robust covariance to a model during fit
#
# - Subsequent predictions will be made with the robust covariance

# %%
lm_robust_hc0 = LinearRegression().fit(X=X, y=y, cov_type="HC0", alpha=0.05, target_name="HouseValHC0")
lm_robust_hc1 = LinearRegression().fit(X=X, y=y, cov_type="HC1", alpha=0.05, target_name="HouseValHC1")
lm_robust_hc2 = LinearRegression().fit(X=X, y=y, cov_type="HC2", alpha=0.05, target_name="HouseValHC2")
lm_robust_hc3 = LinearRegression().fit(X=X, y=y, cov_type="HC3", alpha=0.05, target_name="HouseValHC3")

# %%
# Compare to the nonrobust model

print(summary(lm, lm_robust_hc0, lm_robust_hc1, lm_robust_hc2, lm_robust_hc3))
# Out:
# =========================================================================================================
# OLS Regression Results
# ---------------------------------------------------------------------------------------------------------
# Dependent:                        MedHouseVal    HouseValHC0    HouseValHC1    HouseValHC2    HouseValHC3
# ---------------------------------------------------------------------------------------------------------
#
# const                              -0.3857***     -0.3857***     -0.3857***     -0.3857***     -0.3857***
#                                      (0.0247)       (0.0905)       (0.0906)       (0.1022)       (0.1161)
#
# MedInc                              0.5374***      0.5374***      0.5374***      0.5374***      0.5374***
#                                      (0.0041)       (0.0106)       (0.0106)       (0.0114)       (0.0124)
#
# HouseAge                            0.0159***      0.0159***      0.0159***      0.0159***      0.0159***
#                                      (0.0004)       (0.0006)       (0.0006)       (0.0006)       (0.0006)
#
# AveRooms                           -0.2139***     -0.2139***     -0.2139***     -0.2139***     -0.2139***
#                                      (0.0060)       (0.0189)       (0.0189)       (0.0206)       (0.0226)
#
# AveBedrms                           0.9985***      0.9985***      0.9985***      0.9985***      0.9985***
#                                      (0.0295)       (0.1023)       (0.1023)       (0.1156)       (0.1316)
#
# AveOccup                           -0.0047***     -0.0047***     -0.0047***     -0.0047***       -0.0047*
#                                      (0.0005)       (0.0011)       (0.0011)       (0.0016)       (0.0024)
#
# ---------------------------------------------------------------------------------------------------------
# R-squared                               0.539          0.539          0.539          0.539          0.539
# Adjusted R-squared                      0.539          0.539          0.539          0.539          0.539
# F Statistic                          4830.447       4830.447       4830.447       4830.447       4830.447
# Observations                        20640.000      20640.000      20640.000      20640.000      20640.000
# Log Likelihood                     -24244.367     -24244.367     -24244.367     -24244.367     -24244.367
# AIC                                 48500.734      48500.734      48500.734      48500.734      48500.734
# BIC                                 48548.344      48548.344      48548.344      48548.344      48548.344
# TSS                                 27483.198      27483.198      27483.198      27483.198      27483.198
# RSS                                 12662.112      12662.112      12662.112      12662.112      12662.112
# ESS                                 14821.086      14821.086      14821.086      14821.086      14821.086
# MSE                                     0.614          0.614          0.614          0.614          0.614
# =========================================================================================================
# *p<0.1; **p<0.05; ***p<0.01
